# %%
# Name - SAWAN KUMAR
# Email ID - sawankumar19062001@gmail.com
# Contact Number - 8882022191
# Course - Data Science with Generative AI
# Module - 7
# Assignment - Files , Exceptional handling , Logging and Memory Management




# Theory Question




# 1. What is the difference between interpreted and compiled languages?
  - Interpreted languages like Python execute code line by line, while
  - Compiled languages like C++ translate code to machine language before execution, resulting in faster performance.

# 2. What is exception handling in Python?
  - Exception handling allows you to gracefully manage errors in your program using try, except, else, and finally blocks.

# 3. What is the purpose of the finally block in exception handling?
  - The finally block ensures that important code, such as file closing or cleanup, runs regardless of whether an exception occurred.

# 4. What is logging in Python?
  - Logging helps track events that happen when software runs.
    > It is useful for debugging, auditing, and running diagnostics.

# 5. What is the significance of the __del__ method in Python?
  - The __del__ method is a destructor in Python, automatically called when an object is about to be destroyed.

# 6. What is the difference between import and from ... import in Python?
  - 'import' loads the whole module, while
  - 'from module import' loads specific attributes or functions from a module.

# 7. How can you handle multiple exceptions in Python?
  - You can handle multiple exceptions by grouping them in a tuple within one except clause.

# 8. What is the purpose of the with statement when handling files in Python?
  - The 'with' statement simplifies exception handling in file operations by ensuring that files are properly closed after their suite finishes.

# 9. What is the difference between multithreading and multiprocessing?
  - Multithreading runs multiple threads in one process, sharing memory.
  - Multiprocessing runs separate processes with separate memory, suitable for CPU-bound tasks.

# 10. What are the advantages of using logging in a program?
  - Logging makes it easier to trace bugs and understand the application's behavior without disrupting program flow.

# 11. What is memory management in Python?
  - Python manages memory using reference counting and garbage collection, freeing memory automatically when objects are no longer used.

# 12. What are the basic steps involved in exception handling in Python?
  - Python handles exceptions in the order:
    try (run code) -> except (handle errors) -> else (run if no error) -> finally (always runs).

# 13. Why is memory management important in Python?
  - Good memory management ensures :
    > efficient use of system resources and
    > prevents crashes or slow performance due to memory leaks.

# 14. What is the role of try and except in exception handling?
  - These keywords are used to catch and handle exceptions, preventing abrupt program termination.

# 15. How does Python's garbage collection system work?
  - Python's garbage collector automatically reclaims unused memory by removing objects no longer referenced.

# 16. What is the purpose of the else block in exception handling?
  - The else block in exception handling runs only when no exception occurs in the try block.

# 17. What are the common logging levels in Python?
  - Logging levels include :
    > DEBUG (detailed info),
    > INFO (confirmation),
    > WARNING (potential issues),
    > ERROR (serious problems), and
    > CRITICAL (very serious errors).

# 18. What is the difference between os.fork() and multiprocessing in Python?
  - os.fork creates a child process (Unix only), while
  - Multiprocessing works on all platforms and is more flexible and safer in Python.

# 19. What is the importance of closing a file in Python?
  - It is important to close a file after use to release system resources and avoid data corruption.

# 20. What is the difference between file.read() and file.readline() in Python?
  - file.read() reads the entire file, while
  - file.readline() reads one line at a time, which is more memory-efficient for large files.

# 21. What is the logging module in Python used for?
  - The logging module provides flexible ways to record log messages to files, streams, or other outputs.

# 22. What is the os module in Python used for in file handling?
  - The os module provides a way to interact with the operating system, such as file and directory operations.

# 23. What are the challenges associated with memory management in Python?
  - Python's memory management can struggle with circular references and may lead to memory leaks in poorly written code.

# 24. How do you raise an exception manually in Python?
  - Custom exceptions can be raised using the 'raise' keyword to signal an error condition explicitly.

# 25. Why is it important to use multithreading in certain applications?
  - Multithreading is useful for I/O-bound applications, allowing multiple tasks to run concurrently and improving responsiveness.






# Practical Question





# 1. How can you open a file for writing in Python and write a string to it?

      with open("file.txt", "w") as f:
          f.write("Hello, this is a test message.")

# 2. Write a Python program to read the contents of a file and print each lineF

      with open("file.txt", "r") as f:
          for line in f:
              print(line.strip())

# 3. How would you handle a case where the file doesn't exist while trying to open it for reading?

      try:
          open("nofile.txt")
      except FileNotFoundError:
          print("The specified file was not found.")

# 4. Write a Python script that reads from one file and writes its content to another file.

      with open("file1.txt") as f1, open("file2.txt", "w") as f2:
          f2.write(f1.read())

# 5. How would you catch and handle division by zero error in Python?

      try:
          result = 10 / 0
      except ZeroDivisionError:
          print("Cannot divide by zero.")

# 6. Write a Python program that logs an error message to a log file when a division by zero exception occurs.

      import logging
      logging.basicConfig(level=logging.ERROR)
      try:
          1 / 0
      except ZeroDivisionError as e:
          logging.error(f"An error occurred: {e}")

# 7. How do you log information at different levels (INFO, ERROR, WARNING) in Python using the logging module?

      logging.info("Program started")
      logging.warning("Low disk space")
      logging.error("Failed to save file")

# 8. Write a program to handle a file opening error using exception handling.

      try:
          with open("nofile.txt") as f:
              print(f.read())
      except Exception as e:
          print(f"An error occurred: {e}")

# 9. How can you read a file line by line and store its content in a list in Python?

      with open("file.txt") as f:
          lines = f.readlines()
          print(lines)

# 10. How can you append data to an existing file in Python?

      with open("file.txt", "a") as f:
          f.write("\nAppended line.")

# 11. Write a Python program that uses a try-except block to handle an error when attempting to access a dictionary key that doesn't exist.

      try:
          my_dict = {"name": "Alice"}
          print(my_dict["age"])
      except KeyError:
          print("The specified key does not exist.")

# 12. Write a program that demonstrates using multiple except blocks to handle different types of exceptions.

      try:
          lst = [1, 2]
          print(lst[3])
      except IndexError:
          print("List index out of range")
      except Exception as e:
          print(f"Unexpected error: {e}")

# 13. How would you check if a file exists before attempting to read it in Python?

      import os
      if os.path.exists("file.txt"):
          print("File exists")
      else:
          print("File does not exist")

# 14. Write a program that uses the logging module to log both informational and error messages.

      logging.info("Process started")
      logging.error("Unable to complete process")

# 15. Write a Python program that prints the content of a file and handles the case when the file is empty.

      with open("file.txt") as f:
          content = f.read()
          if not content:
              print("The file is empty")

# 16. Demonstrate how to use memory profiling to check the memory usage of a small program.

      # Step 1: Install memory_profiler using pip:
      # pip install memory_profiler

      # Step 2: Import the profile decorator from memory_profiler

          from memory_profiler import profile

      # Step 3: Use the @profile decorator on the function you want to monitor

          @profile
          def create_large_list():
          # This function creates a large list, which uses a noticeable amount of memory
          data = [i * 2 for i in range(1000000)]
          return data

      # Step 4: Call the function

          if __name__ == "__main__":
              create_large_list()

      # Step 5: Run this script using the command below to see memory usage line by line:
      # python -m memory_profiler filename.py

      # Example Output:
      # Line #    Mem usage    Increment   Line Contents
      # ================================================
      #     8     18.2 MiB     18.2 MiB   @profile
      #     9                            def create_large_list():
      #    10     44.5 MiB     26.3 MiB       data = [i * 2 for i in range(1000000)]
      #    11     44.5 MiB      0.0 MiB       return data


# 17. Write a Python program to create and write a list of numbers to a file, one number per line.

      with open("nums.txt", "w") as f:
          for i in range(10):
              f.write(f"{i}\n")

# 18. How would you implement a basic logging setup that logs to a file with rotation after 1MB?

      from logging.handlers import RotatingFileHandler
      logger = logging.getLogger("RotatingLogger")
      handler = RotatingFileHandler("log.log", maxBytes=1000, backupCount=1)
      logger.addHandler(handler)
      logger.setLevel(logging.INFO)
      logger.info("Logging with rotation setup.")

# 19. Write a program that handles both IndexError and KeyError using a try-except block.

      try:
          data = [1, 2]
          print(data[3])
      except (IndexError, KeyError):
          print("An index or key error occurred.")

# 20. How would you open a file and read its contents using a context manager in Python?

      with open("file.txt") as f:
          print(f.read())

# 21. Write a Python program that reads a file and prints the number of occurrences of a specific word.

      word_to_count = "python"
      count = 0
      with open("file.txt") as f:
          for line in f:
              count += line.lower().count(word_to_count)
      print(f"The word '{word_to_count}' occurred {count} times.")

# 22. How can you check if a file is empty before attempting to read its contents?

      if os.path.exists("file.txt") and os.path.getsize("file.txt") == 0:
          print("The file is empty")

# 23. Write a Python program that writes to a log file when an error occurs during file handling.

      try:
          open("nofile.txt")
      except Exception as e:
          logging.error(f"Error opening file: {e}")
